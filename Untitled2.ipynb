# %% [markdown]
# <a href="https://colab.research.google.com/github/ToluSh/Classwork/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def test1(x,y):
    x=input("firstname")
    y=input("lastname")
    print(x[-1:0]+""+y[-1:0])

# %%
def test2(n):
    n=int(a)
    a=input("enter a number")
    return n+nn+nnn

# %%
num= int()
if num%2==1:
    print("This is an odd number")
else:
    print("This is an even number")
# Out:
# This is an even number

# %%
for i in range (2000,3200):
    if i%7 == 0 and i%5 != 0:
        print(i)
    else:  
        print("This satisfies only one condition")
# Out:
# This satisfies only one condition
# This satisfies only one condition
# 2002
# This satisfies only one condition
# This satisfies only one condition
# This satisfies only one condition
# This satisfies only one condition
# This satisfies only one condition
# This satisfies only one condition
# 2009
# This satisfies only one condition
# This satisfies only one condition
# This satisfies only one condition
# This satisfies only one condition
# This satisfies only one condition
# This satisfies only one condition
# 2016
# This satisfies only one condition
# This satisfies only one condition
# This satisfies only one condition
# This satisfies only one condition
# This satisfies only one condition
# This satisfies only one condition
# 2023
# This satisfies only one condition
# This satisfies only one condition
# This satisfies only one condition
# This satisfies only one condition
# This satisfies only one condition
# This satisfies only one condition
# This satisfies only one condition
# ...

# %%
def test5 (x):
    x=int(input("enter a number for a"))
    return fact(x)

# %%
def test6 (x):
    x= Jasmine
    for i in x[0,len(x),2]:
        print(x[i])

# %%
def discount (x,y):
    x=input("price")
    y=input("rate")
    return x*y
    if x>= 500:
        y = int(0.5)
        print(discount)
    elif x(200,500) :
        y = int(0.3)
        print(discount)
    else:
        y = int(0.1)
        print(discount)
